# %% [markdown]
# # Machine Learning, DNN for regression
#
# ### Description of the dataset NO2
# The dataset that we are going to use for this lesson was obtained from the StatLib repository. http://lib.stat.cmu.edu/datasets/ (NO2).
# The data are a subsample of 500 observations from a data set that originate in a study where air pollution at a road is related to traffic volume and meteorological variables, collected by the Norwegian Public Roads Administration. The response variable (column 1) consist of hourly values of the logarithm of the concentration of NO2 (particles), measured at Alnabru in Oslo, Norway, between October 2001 and August 2003. The predictor variables (columns 2 to 8) are the logarithm of the number of cars per hour, temperature $2$ meters above ground (degree C), wind speed (meters/second), the temperature difference between $25$ and $2$ meters above ground (degree C), wind direction (degrees between 0 and 360), hour of day and day number from October 1 2001. Submitted by Magne Aldrin (magne.aldrin@nr.no). [28/Jul/04] (19kbytes)
#
#
# Target variable:
# - NO2 concentration (log) [lno2]
#
# Features:
# - log of car per hour [lc]
#
# - temperature 2 meters above the ground (degree C)[t2]
#
# - wind speed (meters/seconds) [ws]
#
# - temperature difference between 25 meters and 2 meters above the ground (degree C) [td25]
#
# - wind direction (degrees between 0 and 360) [wd]
#
# - hour of day [hd] average house occupancy
#
# - day number from Oct. 1 2001 [dn]

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from math import sqrt
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras import metrics

# %% [markdown]
# ### ASSIGNING LABELS TO FEATURES
# We assign the labels to the corresponding columns to have a clean representation of the dataset

# %%
features = ['lc', 't2', 'ws', 'td25', 'wd', 'hd', 'dn']

# %% [markdown]
# ### CREATE THE DNN LARGE NETWORK MODEL
#
#
# <img src="images/DNN-all.png" alt="DNN Model Large" width="500"/>
#
#
# #### Create the network as indicated in the image above. All activation functions should be ReLU. Have a look at the slide for hints on the code to use.

# %%
def create_model_large():
    model = Sequential()
    model.add(Dense(10, input_dim = X_train.shape[1], activation = "relu"))
    model.add(Dense(30, activation = "relu"))
    model.add(Dense(40, activation = "relu"))
    model.add(Dense(1))
    model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = ['mae'])
    return model

# %% [markdown]
# ### CREATE THE TINY ANN MODEL
#
# #### Create an ANN with 1 layer containing 3 neurons (model tiny), alla activation functions should be ReLU.

# %%
def create_model_tiny():
    model = Sequential()
    model.add(Dense(3, input_dim = X_train.shape[1], activation = "relu"))
    model.add(Dense(1))
    model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = [metrics.MeanAbsoluteError()])
    return model

# %% [markdown]
# ### CREATE THE SMALL ANN MODEL
#
# #### Create an ANN with 1 layer containing 10 neurons (model small), alla activation functions should be ReLU.

# %%
def create_model_small():
    model = Sequential()
    model.add(Dense(10, input_dim = X_train.shape[1], activation = "relu"))
    model.add(Dense(1))
    model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = [metrics.MeanAbsoluteError()])
    return model

# %% [markdown]
# ### CREATE THE MEDIUM DNN MODEL
#
# #### Create an DNN with 2 layers containing respectively 10 and 30 neurons (model medium), alla activation functions should be ReLU.

# %%
def create_model_medium(input_size):
    model = Sequential()    
    model.add(Dense(10, input_dim = X_train.shape[1], activation = "relu"))
    model.add(Dense(30, activation = "relu"))
    model.add(Dense(1))
    model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = ['mae'])
    return model

# %% [markdown]
# ### Evaluating the model
#
# The following functions computes the Root Mean Squared Error and the Normalized Root Mean Squared Error between the groud thruth (real) and inferred (pred) responses.

# %%
def RMSE(real, pred):
    return sqrt(mean_squared_error(real, pred))

def NRMSE(real, pred):
    return sqrt(mean_squared_error(real, pred)/(real.max() - real.min()))

# %% [markdown]
# ### Loading  the data
#
# #### Using the panda library to load data, provide a descriptive summary

# %%
# Load data
df = pd.read_csv('NO2.csv', index_col=False)

# Descriptive statistics summary
df.describe()
# Out:
#              lno2          lc          t2          ws        td25          wd  \
# count  500.000000  500.000000  500.000000  500.000000  500.000000  500.000000
# mean     3.698368    6.973342    0.847400    3.056000    0.149400  143.370400
# std      0.750597    1.087166    6.524636    1.784172    1.065237   86.510213
# min      1.223780    4.127130  -18.600000    0.300000   -5.400000    2.000000
# 25%      3.213862    6.175842   -3.900000    1.675000   -0.200000   72.000000
# 50%      3.848020    7.425360    1.100000    2.800000    0.000000   97.000000
# 75%      4.216930    7.793175    4.900000    4.200000    0.600000  220.000000
# max      6.395090    8.348540   21.100000    9.900000    4.300000  359.000000
#
#                hd          dn
# count  500.000000  500.000000
# mean    12.382000  310.474000
# std      6.802693  200.977754
# min      1.000000   32.000000
# 25%      6.000000  118.750000
# 50%     12.500000  212.000000
# 75%     18.000000  513.000000
# max     24.000000  608.000000

# %% [markdown]
# ### Visualzing the relationships among the features in the data
#
# #### Compute and visualize a correlation matring among the features (using the seaborn library).

# %%
# Correlation matrix
corrmat = df.corr()

# Generate a mask for the upper triangle
matrix = np.triu(corrmat)
f, ax = plt.subplots(figsize=(12, 9))
sns.set(font_scale=1)
sns.heatmap(corrmat, vmin=-1, vmax=1, center= 0, square=True, annot=True, annot_kws={'size': 8}, mask=matrix, fmt='.2g', cmap= 'coolwarm')

plt.show()

# %% [markdown]
# ### Standizing the data
#
# #### Standardize features to have 0 mean, sigma 1 and range between -1 and 1.  Do not standardize the response.

# %%
# Standardizing data
sc= MinMaxScaler(feature_range=(-1,1))

for var in features:
    if(var != 'lno2'):
        df[var] = sc.fit_transform(df[var].values.reshape(-1, 1))

# %% [markdown]
# ### Preparing the data for training, using validation set approach
#
# #### Remove labels and create the validation set.

# %%
#NumPy representation of the data frame (removing labels)
n_df = df.to_numpy() #df=df.values

#divide predictors from features
X = n_df[:, 1:];
y = n_df[:, 0]; 

seed = 7
np.random.seed(seed)

# split dataset in 75% for traininig and 25% for testing (500 -> 375,125)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=seed)

# split training in 70% for traininig and 30% for validating (375 -> 300,75)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.30, random_state = seed);

# Model creation (choose between tiny, small, medium and large by using the appropriate function)
model = create_model_large()
model.summary()
# Out:
# /Users/paoloimbriani/miniconda3/envs/ai-lab/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 10)             │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 30)             │           330 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 40)             │         1,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            41 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,691 (6.61 KB)
#  Trainable params: 1,691 (6.61 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Fit the DNN to the data

# %%
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=150, batch_size=32)
# Out:
# Epoch 1/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 13.7588 - mae: 3.6304 - val_loss: 12.8790 - val_mae: 3.5130
# Epoch 2/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.4293 - mae: 3.4442 - val_loss: 11.5156 - val_mae: 3.3149
# Epoch 3/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.8866 - mae: 3.2126 - val_loss: 9.8717 - val_mae: 3.0564
# Epoch 4/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.9808 - mae: 2.8934 - val_loss: 7.8610 - val_mae: 2.6987
# Epoch 5/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6905 - mae: 2.4464 - val_loss: 5.5865 - val_mae: 2.2136
# Epoch 6/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4169 - mae: 1.9008 - val_loss: 3.4710 - val_mae: 1.6727
# Epoch 7/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6809 - mae: 1.4001 - val_loss: 2.1734 - val_mae: 1.2568
# Epoch 8/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9128 - mae: 1.1523 - val_loss: 1.6741 - val_mae: 1.0672
# Epoch 9/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6060 - mae: 1.0378 - val_loss: 1.3414 - val_mae: 0.9436
# Epoch 10/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3096 - mae: 0.9420 - val_loss: 1.0876 - val_mae: 0.8440
# Epoch 11/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0592 - mae: 0.8468 - val_loss: 0.9377 - val_mae: 0.7772
# Epoch 12/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9181 - mae: 0.7850 - val_loss: 0.8178 - val_mae: 0.7251
# Epoch 13/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8137 - mae: 0.7368 - val_loss: 0.7473 - val_mae: 0.6947
# Epoch 14/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7449 - mae: 0.7020 - val_loss: 0.7028 - val_mae: 0.6734
# Epoch 15/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6993 - mae: 0.6772 - val_loss: 0.6688 - val_mae: 0.6568
# Epoch 16/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6634 - mae: 0.6569 - val_loss: 0.6396 - val_mae: 0.6433
# Epoch 17/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6275 - mae: 0.6360 - val_loss: 0.6083 - val_mae: 0.6275
# Epoch 18/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5988 - mae: 0.6184 - val_loss: 0.5830 - val_mae: 0.6161
# Epoch 19/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5728 - mae: 0.6046 - val_loss: 0.5626 - val_mae: 0.6053
# Epoch 20/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5485 - mae: 0.5855 - val_loss: 0.5417 - val_mae: 0.5896
# Epoch 21/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5248 - mae: 0.5685 - val_loss: 0.5209 - val_mae: 0.5792
# Epoch 22/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5020 - mae: 0.5575 - val_loss: 0.5062 - val_mae: 0.5728
# Epoch 23/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4840 - mae: 0.5455 - val_loss: 0.4882 - val_mae: 0.5627
# Epoch 24/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4663 - mae: 0.5338 - val_loss: 0.4716 - val_mae: 0.5524
# Epoch 25/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4519 - mae: 0.5217 - val_loss: 0.4592 - val_mae: 0.5419
# Epoch 26/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4383 - mae: 0.5112 - val_loss: 0.4476 - val_mae: 0.5329
# Epoch 27/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4241 - mae: 0.5027 - val_loss: 0.4353 - val_mae: 0.5312
# Epoch 28/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4079 - mae: 0.4909 - val_loss: 0.4217 - val_mae: 0.5217
# Epoch 29/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3960 - mae: 0.4825 - val_loss: 0.4127 - val_mae: 0.5131
# Epoch 30/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3841 - mae: 0.4756 - val_loss: 0.3995 - val_mae: 0.5095
# Epoch 31/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3730 - mae: 0.4690 - val_loss: 0.3900 - val_mae: 0.5052
# Epoch 32/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3660 - mae: 0.4648 - val_loss: 0.3817 - val_mae: 0.4994
# Epoch 33/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3565 - mae: 0.4581 - val_loss: 0.3719 - val_mae: 0.4922
# Epoch 34/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3490 - mae: 0.4537 - val_loss: 0.3671 - val_mae: 0.4853
# Epoch 35/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3408 - mae: 0.4466 - val_loss: 0.3617 - val_mae: 0.4830
# Epoch 36/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3351 - mae: 0.4427 - val_loss: 0.3593 - val_mae: 0.4820
# Epoch 37/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3293 - mae: 0.4391 - val_loss: 0.3538 - val_mae: 0.4720
# Epoch 38/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3235 - mae: 0.4353 - val_loss: 0.3480 - val_mae: 0.4672
# Epoch 39/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3179 - mae: 0.4324 - val_loss: 0.3436 - val_mae: 0.4661
# Epoch 40/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3130 - mae: 0.4298 - val_loss: 0.3410 - val_mae: 0.4635
# Epoch 41/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3088 - mae: 0.4274 - val_loss: 0.3384 - val_mae: 0.4578
# Epoch 42/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3109 - mae: 0.4295 - val_loss: 0.3409 - val_mae: 0.4587
# Epoch 43/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.
150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2126 - mae: 0.3582 - val_loss: 0.3044 - val_mae: 0.4377
# Epoch 142/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2096 - mae: 0.3576 - val_loss: 0.3026 - val_mae: 0.4407
# Epoch 143/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2097 - mae: 0.3578 - val_loss: 0.3034 - val_mae: 0.4391
# Epoch 144/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2106 - mae: 0.3597 - val_loss: 0.3030 - val_mae: 0.4439
# Epoch 145/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2081 - mae: 0.3566 - val_loss: 0.3038 - val_mae: 0.4409
# Epoch 146/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2075 - mae: 0.3547 - val_loss: 0.3017 - val_mae: 0.4375
# Epoch 147/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2065 - mae: 0.3542 - val_loss: 0.2987 - val_mae: 0.4389
# Epoch 148/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2073 - mae: 0.3559 - val_loss: 0.2982 - val_mae: 0.4382
# Epoch 149/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2096 - mae: 0.3585 - val_loss: 0.3042 - val_mae: 0.4391
# Epoch 150/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2088 - mae: 0.3563 - val_loss: 0.3068 - val_mae: 0.4397

# %% [markdown]
# ### Evaluate accuracy and loss of your model. This is how your plots should look like:
# <table><tr>
# <td> <img src="images/accuracy.png" style="width: 500px;"/> </td>
# <td> <img src="images/loss.png" style="width: 500px;"/> </td>
# </tr></table>

# %%
# Summarize history for accuracy
plt.plot(history.history['mae'])
plt.plot(history.history['val_mae'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
# Summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %% [markdown]
# ### Now evaluate the predictions of your model in terms of RMSE and NRMSE. You should obtain plots like these:
# <table><tr>
# <td> <img src="images/inference.png" style="width: 500px;"/> </td>
# <td> <img src="images/inference_diff.png" style="width: 500px;"/> </td>
# </tr></table>

# %%
# Prediction
pred = model.predict(X_test).reshape(1,-1)[0]

rmse = RMSE(y_test, pred)
nrmse = NRMSE(y_test, pred)


print("rmse : ",rmse,"  nrmse : ",nrmse)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# rmse :  0.5373599001908519   nrmse :  0.2660885594834125

# %%
my_x=np.arange(0,len(X_test[:,0]),1)

fig = plt.figure(figsize=(20,10))
plt.scatter(my_x, y_test, label='Real', color='blue', marker='o')
plt.scatter(my_x, pred, label='Inference', color='red', marker='s')
plt.title(f'Inference of log(NO2)  rmse: {rmse:.3f}, nrmse: {nrmse:.3f}')
plt.ylabel('log(NO2)')
plt.xlabel('readings (rows of file)')
plt.grid()
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(20,10))
my_d = abs(y_test-pred)

plt.bar(my_x,my_d)
plt.title(f'Inference of log(NO2) -- absolute difference between inference and ground truth rmse: {rmse:.3f}, nrmse: {nrmse:.3f}')
plt.ylabel('absolute value of difference in inference [log(NO2)]')
plt.xlabel('readings (rows of file)')
plt.grid()
plt.show()

# %% [markdown]
# ## Question 1 (connecting to the RLs question)
# Consider a regression task using Deep Neural Networks (DNNs) and consider the dataset NO2 (the same code as the ML laboratory). Create a DNN consisting of three hidden layers, each of 64 nodes activated with ReLU, and one output. If we perform the training and evaluation with the following code (i.e., the one you should have completed during the lab)

# %%
def create_model():
    model = Sequential()
    model.add(Dense(10, input_dim = X_train.shape[1], activation = "relu"))
    model.add(Dense(64, activation = "relu"))
    model.add(Dense(64, activation = "relu"))
    model.add(Dense(64, activation = "relu"))
    model.add(Dense(1))

    model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = [metrics.MeanAbsoluteError()])
    return model

# %%
#NumPy representation of the data frame (removing labels)
n_df = df.to_numpy() 

#divide predictors from features
X = n_df[:, 1:]; # All features (cols from 2 to 8)
y = n_df[:, 0]; # Only predictors (col 1)

seed = 7
np.random.seed(seed)

# split dataset in 75% for training and 25% for testing (500 -> 375,125)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=seed)

# split training in 70% for training and 30% for validating (375 -> 300,75)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.30, random_state = seed);#insert your code here

# Model creation (choose between tiny, small, medium, and large by using the appropriate function)
model = create_model()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=150, batch_size=32)
# Out:
# Epoch 1/150
# /Users/paoloimbriani/miniconda3/envs/ai-lab/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 13.9481 - mean_absolute_error: 3.6562 - val_loss: 11.9519 - val_mean_absolute_error: 3.3821
# Epoch 2/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.6621 - mean_absolute_error: 3.1820 - val_loss: 8.3933 - val_mean_absolute_error: 2.8112
# Epoch 3/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6529 - mean_absolute_error: 2.4608 - val_loss: 3.9599 - val_mean_absolute_error: 1.8542
# Epoch 4/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5422 - mean_absolute_error: 1.3500 - val_loss: 1.1706 - val_mean_absolute_error: 0.8345
# Epoch 5/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5712 - mean_absolute_error: 0.9983 - val_loss: 1.3697 - val_mean_absolute_error: 0.9700
# Epoch 6/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3111 - mean_absolute_error: 0.9175 - val_loss: 0.9156 - val_mean_absolute_error: 0.7196
# Epoch 7/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0249 - mean_absolute_error: 0.7958 - val_loss: 0.8727 - val_mean_absolute_error: 0.7119
# Epoch 8/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8764 - mean_absolute_error: 0.7314 - val_loss: 0.7193 - val_mean_absolute_error: 0.6196
# Epoch 9/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7608 - mean_absolute_error: 0.6796 - val_loss: 0.6416 - val_mean_absolute_error: 0.5860
# Epoch 10/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6372 - mean_absolute_error: 0.6200 - val_loss: 0.5749 - val_mean_absolute_error: 0.5614
# Epoch 11/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5873 - mean_absolute_error: 0.5982 - val_loss: 0.4985 - val_mean_absolute_error: 0.5264
# Epoch 12/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5048 - mean_absolute_error: 0.5481 - val_loss: 0.4610 - val_mean_absolute_error: 0.5041
# Epoch 13/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4531 - mean_absolute_error: 0.5229 - val_loss: 0.4200 - val_mean_absolute_error: 0.4829
# Epoch 14/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4045 - mean_absolute_error: 0.4944 - val_loss: 0.3956 - val_mean_absolute_error: 0.4714
# Epoch 15/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3706 - mean_absolute_error: 0.4706 - val_loss: 0.3802 - val_mean_absolute_error: 0.4627
# Epoch 16/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3494 - mean_absolute_error: 0.4557 - val_loss: 0.3707 - val_mean_absolute_error: 0.4563
# Epoch 17/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3332 - mean_absolute_error: 0.4456 - val_loss: 0.3586 - val_mean_absolute_error: 0.4542
# Epoch 18/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3237 - mean_absolute_error: 0.4408 - val_loss: 0.3528 - val_mean_absolute_error: 0.4529
# Epoch 19/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3106 - mean_absolute_error: 0.4336 - val_loss: 0.3463 - val_mean_absolute_error: 0.4547
# Epoch 20/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2990 - mean_absolute_error: 0.4253 - val_loss: 0.3414 - val_mean_absolute_error: 0.4500
# Epoch 21/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2984 - mean_absolute_error: 0.4220 - val_loss: 0.3452 - val_mean_absolute_error: 0.4577
# Epoch 22/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2932 - mean_absolute_error: 0.4245 - val_loss: 0.3422 - val_mean_absolute_error: 0.4478
# Epoch 23/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2826 - mean_absolute_error: 0.4134 - val_loss: 0.3400 - val_mean_absolute_error: 0.4498
# Epoch 24/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2722 - mean_absolute_error: 0.4031 - val_loss: 0.3340 - val_mean_absolute_error: 0.4434
# Epoch 25/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2669 - mean_absolute_error: 0.3976 - val_loss: 0.3286 - val_mean_absolute_error: 0.4433
# Epoch 26/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2688 - mean_absolute_error: 0.4011 - val_loss: 0.3246 - val_mean_absolute_error: 0.4376
# Epoch 27/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2648 - mean_absolute_error: 0.3973 - val_loss: 0.3209 - val_mean_absolute_error: 0.4348
# Epoch 28/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2592 - mean_absolute_error: 0.3967 - val_loss: 0.3191 - val_mean_absolute_error: 0.4390
# Epoch 29/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2515 - mean_absolute_error: 0.3914 - val_loss: 0.3172 - val_mean_absolute_error: 0.4363
# Epoch 30/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2528 - mean_absolute_error: 0.3907 - val_loss: 0.3144 - val_mean_absolute_error: 0.4349
# Epoch 31/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2477 - mean_absolute_error: 0.3862 - val_loss: 0.3107 - val_mean_absolute_error: 0.4311
# Epoch 32/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2458 - mean_absolute_error: 0.3852 - val_loss: 0.3135 - val_mean_absolute_error: 0.4322
# Epoch 33/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2430 - mean_absolute_error: 0.3830 - val_loss: 0.3104 - val_mean_absolute_error: 0.4281
# Epoch 34/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2434 - mean_absolute_error: 0.3832 - val_loss: 0.3064 - val_mean_absolute_error: 0.4295
# Epoch 35/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2392 - mean_absolute_error: 0.3790 - val_loss: 0.3076 - val_mean_absolute_error: 0.4296
# Epoch 36/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2366 - mean_absolute_error: 0.3755 - val_loss: 0.3090 - val_mean_absolute_error: 0.4269
# Epoch 37/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2367 - mean_absolute_error: 0.3778 - val_loss: 0.3102 - val_mean_absolute_error: 0.4278
# Epoch 38/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2338 - mean_absolute_error: 0.3744 - val_loss: 0.3097 - val_mean_absolute_error: 0.4287
# Epoch 39/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2327 - mean_absolute_error: 0.3734 - val_loss: 0.3074 - val_mean_absolute_error: 0.4339
# Epoch 40/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2320 - mean_absolute_error: 0.3726 - val_loss: 0.3059 - val_mean_absolute_error: 0.4296
# Epoch 41/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2342 - mean_absolute_error: 0.3720 - val_loss: 0.3024 - val_mean_absolute_error: 0.4252
# Epoch 42/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2257 - mean_absolute_error: 0.3664 - val_loss: 0.3023 - val_mean_absolute_error: 0.4279
# Epoch 43/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2239 - mean_absolute_error: 0.3665 - val_loss: 0.3004 - val_mean_absolute_error: 0.4284
# Epoch 44/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2230 - mean_absolute_error: 0.3643 - val_loss: 0.2975 - val_mean_absolute_error: 0.4235
# Epoch 45/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2207 - mean_absolute_error: 0.3627 - val_loss: 0.2964 - val_mean_absolute_error: 0.4200
# Epoch 46/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2227 - mean_absolute_error: 0.3644 - val_loss: 0.2928 - val_mean_absolute_error: 0.4158
# Epoch 47/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2206 - mean_absolute_error: 0.3638 - val_loss: 0.2897 - val_mean_absolute_error: 0.4188
# Epoch 48/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2197 - mean_absolute_error: 0.3616 - val_loss: 0.2882 - val_mean_absolute_error: 0.4210
# Epoch 49/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2164 - mean_absolute_error: 0.3595 - val_loss: 0.2883 - val_mean_absolute_error: 0.4162
# Epoch 50/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2197 - mean_absolute_error: 0.3611 - val_loss: 0.2946 - val_mean_absolute_error: 0.4172
# Epoch 51/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2193 - mean_absolute_error: 0.3592 - val_loss: 0.2976 - val_mean_absolute_error: 0.4235
# Epoch 52/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2215 - mean_absolute_error: 0.3633 - val_loss: 0.2953 - val_mean_absolute_error: 0.4198
# Epoch 53/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2182 - mean_absolute_error: 0.3636 - val_loss: 0.2989 - val_mean_absolute_error: 0.4312
# Epoch 54/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2089 - mean_absolute_error: 0.3507 - val_loss: 0.3021 - val_mean_absolute_error: 0.4272
# Epoch 55/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2128 - mean_absolute_error: 0.3556 - val_loss: 0.2986 - val_mean_absolute_error: 0.4219
# Epoch 56/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2082 - mean_absolute_error: 0.3513 - val_loss: 0.3022 - val_mean_absolute_error: 0.4203
# Epoch 57/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2077 - mean_absolute_error: 0.3507 - val_loss: 0.2984 - val_mean_absolute_error: 0.4246
# Epoch 58/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2035 - mean_absolute_error: 0.3462 - val_loss: 0.2958 - val_mean_absolute_error: 0.4242
# Epoch 59/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2081 - mean_absolute_error: 0.3521 - val_loss: 0.2971 - val_mean_absolute_error: 0.4266
# Epoch 60/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2056 - mean_absolute_error: 0.3479 - val_loss: 0.2921 - val_mean_absolute_error: 0.4179
# Epoch 61/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2085 - mean_absolute_error: 0.3503 - val_loss: 0.2971 - val_mean_absolute_error: 0.4168
# Epoch 62/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2030 - mean_absolute_error: 0.3478 - val_loss: 0.2920 - val_mean_absolute_error: 0.4137
# Epoch 63/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1988 - mean_absolute_error: 0.3434 - val_loss: 0.2865 - val_mean_absolute_error: 0.4208
# Epoch 64/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2051 - mean_absolute_error: 0.3500 - val_loss: 0.2925 - val_mean_absolute_error: 0.4215
# Epoch 65/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2039 - mean_absolute_error: 0.3495 - val_loss: 0.2916 - val_mean_absolute_error: 0.4185
# Epoch 66/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1952 - mean_absolute_error: 0.3396 - val_loss: 0.2913 - val_mean_absolute_error: 0.4193
# Epoch 67/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1962 - mean_absolute_error: 0.3384 - val_loss: 0.2897 - val_mean_absolute_error: 0.4182
# Epoch 68/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1922 - mean_absolute_error: 0.3360 - val_loss: 0.2897 - val_mean_absolute_error: 0.4193
# Epoch 69/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1910 - mean_absolute_error: 0.3347 - val_loss: 0.2876 - val_mean_absolute_error: 0.4163
# Epoch 70/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1915 - mean_absolute_error: 0.3371 - val_loss: 0.2890 - val_mean_absolute_error: 0.4195
# Epoch 71/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1887 - mean_absolute_error: 0.3340 - val_loss: 0.2867 - val_mean_absolute_error: 0.4185
# Epoch 72/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1896 - mean_absolute_error: 0.3328 - val_loss: 0.2868 - val_mean_absolute_error: 0.4163
# Epoch 73/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1942 - mean_absolute_error: 0.3400 - val_loss: 0.2919 - val_mean_absolute_error: 0.4190
# Epoch 74/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1856 - mean_absolute_error: 0.3303 - val_loss: 0.2914 - val_mean_absolute_error: 0.4247
# Epoch 75/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1896 - mean_absolute_error: 0.3342 - val_loss: 0.2950 - val_mean_absolute_error: 0.4274
# Epoch 76/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1951 - mean_absolute_error: 0.3416 - val_loss: 0.2991 - val_mean_absolute_error: 0.4304
# Epoch 77/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1882 - mean_absolute_error: 0.3352 - val_loss: 0.2876 - val_mean_absolute_error: 0.4213
# Epoch 78/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1835 - mean_absolute_error: 0.3315 - val_loss: 0.2868 - val_mean_absolute_error: 0.4207
# Epoch 79/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1817 - mean_absolute_error: 0.3291 - val_loss: 0.2851 - val_mean_absolute_error: 0.4231
# Epoch 80/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1823 - mean_absolute_error: 0.3297 - val_loss: 0.2882 - val_mean_absolute_error: 0.4220
# Epoch 81/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1816 - mean_absolute_error: 0.3296 - val_loss: 0.2927 - val_mean_absolute_error: 0.4223
# Epoch 82/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1774 - mean_absolute_error: 0.3260 - val_loss: 0.2917 - val_mean_absolute_error: 0.4233
# Epoch 83/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1775 - mean_absolute_error: 0.3232 - val_loss: 0.2897 - val_mean_absolute_error: 0.4253
# Epoch 84/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1752 - mean_absolute_error: 0.3226 - val_loss: 0.2918 - val_mean_absolute_error: 0.4252
# Epoch 85/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1840 - mean_absolute_error: 0.3317 - val_loss: 0.2940 - val_mean_absolute_error: 0.4267
# Epoch 86/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1810 - mean_absolute_error: 0.3310 - val_loss: 0.3022 - val_mean_absolute_error: 0.4288
# Epoch 87/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1803 - mean_absolute_error: 0.3301 - val_loss: 0.2943 - val_mean_absolute_error: 0.4296
# Epoch 88/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1778 - mean_absolute_error: 0.3244 - val_loss: 0.2954 - val_mean_absolute_error: 0.4293
# Epoch 89/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1730 - mean_absolute_error: 0.3207 - val_loss: 0.3005 - val_mean_absolute_error: 0.4294
# Epoch 90/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1822 - mean_absolute_error: 0.3292 - val_loss: 0.2848 - val_mean_absolute_error: 0.4204
# Epoch 91/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1736 - mean_absolute_error: 0.3230 - val_loss: 0.2847 - val_mean_absolute_error: 0.4222
# Epoch 92/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1719 - mean_absolute_error: 0.3218 - val_loss: 0.2853 - val_mean_absolute_error: 0.4206
# Epoch 93/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1737 - mean_absolute_error: 0.3242 - val_loss: 0.2900 - val_mean_absolute_error: 0.4186
# Epoch 94/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1687 - mean_absolute_error: 0.3195 - val_loss: 0.2999 - val_mean_absolute_error: 0.4256
# Epoch 95/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1691 - mean_absolute_error: 0.3199 - val_loss: 0.2958 - val_mean_absolute_error: 0.4225
# Epoch 96/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1656 - mean_absolute_error: 0.3145 - val_loss: 0.3012 - val_mean_absolute_error: 0.4284
# Epoch 97/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1652 - mean_absolute_error: 0.3164 - val_loss: 0.2879 - val_mean_absolute_error: 0.4203
# Epoch 98/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1656 - mean_absolute_error: 0.3138 - val_loss: 0.2926 - val_mean_absolute_error: 0.4225
# Epoch 99/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1639 - mean_absolute_error: 0.3130 - val_loss: 0.2941 - val_mean_absolute_error: 0.4261
# Epoch 100/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1655 - mean_absolute_error: 0.3132 - val_loss: 0.2968 - val_mean_absolute_error: 0.4277
# Epoch 101/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1727 - mean_absolute_error: 0.3225 - val_loss: 0.2947 - val_mean_absolute_error: 0.4248
# Epoch 102/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1662 - mean_absolute_error: 0.3189 - val_loss: 0.2928 - val_mean_absolute_error: 0.4233
# Epoch 103/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1621 - mean_absolute_error: 0.3101 - val_loss: 0.2868 - val_mean_absolute_error: 0.4229
# Epoch 104/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1639 - mean_absolute_error: 0.3122 - val_loss: 0.2854 - val_mean_absolute_error: 0.4212
# Epoch 105/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1676 - mean_absolute_error: 0.3224 - val_loss: 0.3076 - val_mean_absolute_error: 0.4331
# Epoch 106/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1635 - mean_absolute_error: 0.3142 - val_loss: 0.3029 - val_mean_absolute_error: 0.4285
# Epoch 107/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1573 - mean_absolute_error: 0.3079 - val_loss: 0.2939 - val_mean_absolute_error: 0.4262
# Epoch 108/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1589 - mean_absolute_error: 0.3102 - val_loss: 0.3032 - val_mean_absolute_error: 0.4332
# Epoch 109/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1600 - mean_absolute_error: 0.3088 - val_loss: 0.2878 - val_mean_absolute_error: 0.4212
# Epoch 110/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1580 - mean_absolute_error: 0.3075 - val_loss: 0.2972 - val_mean_absolute_error: 0.4264
# Epoch 111/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1608 - mean_absolute_error: 0.3116 - val_loss: 0.2962 - val_mean_absolute_error: 0.4308
# Epoch 112/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1656 - mean_absolute_error: 0.3181 - val_loss: 0.2985 - val_mean_absolute_error: 0.4265
# Epoch 113/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1554 - mean_absolute_error: 0.3045 - val_loss: 0.2899 - val_mean_absolute_error: 0.4215
# Epoch 114/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1500 - mean_absolute_error: 0.2971 - val_loss: 0.2922 - val_mean_absolute_error: 0.4189
# Epoch 115/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1522 - mean_absolute_error: 0.2970 - val_loss: 0.2851 - val_mean_absolute_error: 0.4180
# Epoch 116/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1521 - mean_absolute_error: 0.2986 - val_loss: 0.2886 - val_mean_absolute_error: 0.4196
# Epoch 117/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1489 - mean_absolute_error: 0.2988 - val_loss: 0.2945 - val_mean_absolute_error: 0.4307
# Epoch 118/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1492 - mean_absolute_error: 0.2987 - val_loss: 0.2905 - val_mean_absolute_error: 0.4219
# Epoch 119/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1465 - mean_absolute_error: 0.2927 - val_loss: 0.2922 - val_mean_absolute_error: 0.4198
# Epoch 120/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1516 - mean_absolute_error: 0.2976 - val_loss: 0.2931 - val_mean_absolute_error: 0.4220
# Epoch 121/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1460 - mean_absolute_error: 0.2917 - val_loss: 0.3099 - val_mean_absolute_error: 0.4309
# Epoch 122/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1521 - mean_absolute_error: 0.2990 - val_loss: 0.3024 - val_mean_absolute_error: 0.4267
# Epoch 123/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1481 - mean_absolute_error: 0.2950 - val_loss: 0.2923 - val_mean_absolute_error: 0.4253
# Epoch 124/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1434 - mean_absolute_error: 0.2912 - val_loss: 0.3081 - val_mean_absolute_error: 0.4266
# Epoch 125/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1478 - mean_absolute_error: 0.2974 - val_loss: 0.3028 - val_mean_absolute_error: 0.4222
# Epoch 126/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1631 - mean_absolute_error: 0.3148 - val_loss: 0.2970 - val_mean_absolute_error: 0.4321
# Epoch 127/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1474 - mean_absolute_error: 0.2929 - val_loss: 0.3153 - val_mean_absolute_error: 0.4291
# Epoch 128/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1471 - mean_absolute_error: 0.2940 - val_loss: 0.3128 - val_mean_absolute_error: 0.4371
# Epoch 129/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1479 - mean_absolute_error: 0.2902 - val_loss: 0.2954 - val_mean_absolute_error: 0.4247
# Epoch 130/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1407 - mean_absolute_error: 0.2915 - val_loss: 0.3204 - val_mean_absolute_error: 0.4403
# Epoch 131/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1419 - mean_absolute_error: 0.2910 - val_loss: 0.2889 - val_mean_absolute_error: 0.4227
# Epoch 132/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1344 - mean_absolute_error: 0.2782 - val_loss: 0.2961 - val_mean_absolute_error: 0.4245
# Epoch 133/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1380 - mean_absolute_error: 0.2839 - val_loss: 0.2991 - val_mean_absolute_error: 0.4312
# Epoch 134/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1372 - mean_absolute_error: 0.2851 - val_loss: 0.3126 - val_mean_absolute_error: 0.4348
# Epoch 135/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1330 - mean_absolute_error: 0.2774 - val_loss: 0.2967 - val_mean_absolute_error: 0.4280
# Epoch 136/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1391 - mean_absolute_error: 0.2879 - val_loss: 0.3014 - val_mean_absolute_error: 0.4286
# Epoch 137/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1346 - mean_absolute_error: 0.2805 - val_loss: 0.3247 - val_mean_absolute_error: 0.4390
# Epoch 138/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1414 - mean_absolute_error: 0.2825 - val_loss: 0.2981 - val_mean_absolute_error: 0.4237
# Epoch 139/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1371 - mean_absolute_error: 0.2835 - val_loss: 0.2975 - val_mean_absolute_error: 0.4303
# Epoch 140/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1306 - mean_absolute_error: 0.2744 - val_loss: 0.2929 - val_mean_absolute_error: 0.4212
# Epoch 141/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1327 - mean_absolute_error: 0.2831 - val_loss: 0.3084 - val_mean_absolute_error: 0.4250
# Epoch 142/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1274 - mean_absolute_error: 0.2727 - val_loss: 0.3015 - val_mean_absolute_error: 0.4261
# Epoch 143/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1272 - mean_absolute_error: 0.2700 - val_loss: 0.2985 - val_mean_absolute_error: 0.4241
# Epoch 144/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1295 - mean_absolute_error: 0.2745 - val_loss: 0.3243 - val_mean_absolute_error: 0.4422
# Epoch 145/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1272 - mean_absolute_error: 0.2705 - val_loss: 0.2923 - val_mean_absolute_error: 0.4245
# Epoch 146/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1258 - mean_absolute_error: 0.2680 - val_loss: 0.3004 - val_mean_absolute_error: 0.4197
# Epoch 147/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1274 - mean_absolute_error: 0.2697 - val_loss: 0.3171 - val_mean_absolute_error: 0.4338
# Epoch 148/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1231 - mean_absolute_error: 0.2662 - val_loss: 0.3087 - val_mean_absolute_error: 0.4392
# Epoch 149/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1392 - mean_absolute_error: 0.2893 - val_loss: 0.3273 - val_mean_absolute_error: 0.4435
# Epoch 150/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1240 - mean_absolute_error: 0.2697 - val_loss: 0.3224 - val_mean_absolute_error: 0.4431

# %%
print("Validation loss is: {}".format(history.history["val_loss"][-1]))
# Out:
# Validation loss is: 0.32238566875457764

# %% [markdown]
# ## QUESTION 2
#
# Consider a regression task using Deep Neural Networks (DNNs) and consider the dataset NO2 (the same code as the ML laboratory). Create a DNN consisting of 10 inputs, 3 hidden layers of 64 nodes activated with ReLU, and one output. If we perform the training and evaluation with the following code (i.e., the one you should have completed during the lab)

# %%
print("Validation mean absolute error is: {}".format(history.history["val_mean_absolute_error"][-1]))
# Out:
# Validation mean absolute error is: 0.44311976432800293
